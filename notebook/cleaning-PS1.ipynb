# %%
from astropy.table import Table

# %%
# Read a table from an ASCII file (e.g., a tab-separated values file)
table = Table.read('../True-PN-DR7LAMOST/DR7lamost-True-PN-duplicate-GAIA-PS1-final.ecsv', format='ascii.ecsv')

# %%
table
# Out:
# <Table length=25>
#   Name   MajDiam MinDiam                   FileName                      RA        DEC              DR3Name                 RAdeg      ...  zFlags    ymag   e_ymag  yKmag  e_yKmag  yFlags  angDist_x
#   str8   float64 float64                    str43                     float64    float64             str28                 float64     ...  int64   float64 float64 float64 float64  int64    float64
# -------- ------- ------- ------------------------------------------- ---------- --------- ---------------------------- --------------- ... -------- ------- ------- ------- ------- -------- ---------
#    M 1-4     4.2     4.2           spec-55909-B90903_1_sp16-130.fits   55.43086 52.283422  Gaia DR3 443728125217394688  55.43091537872 ... 16892216  15.103  0.0985 13.5699  0.0157 16892216  0.155449
# ...

# %%
mask = table["rmag"] >= 13.5
table_ = table[mask]

# %%
table_
# Out:
# <Table length=20>
#   Name   MajDiam MinDiam                   FileName                      RA        DEC              DR3Name                 RAdeg      ...  zFlags    ymag   e_ymag  yKmag  e_yKmag  yFlags  angDist_x
#   str8   float64 float64                    str43                     float64    float64             str28                 float64     ...  int64   float64 float64 float64 float64  int64    float64
# -------- ------- ------- ------------------------------------------- ---------- --------- ---------------------------- --------------- ... -------- ------- ------- ------- ------- -------- ---------
#    M 1-4     4.2     4.2           spec-55909-B90903_1_sp16-130.fits   55.43086 52.283422  Gaia DR3 443728125217394688  55.43091537872 ... 16892216  15.103  0.0985 13.5699  0.0157 16892216  0.155449
# ...

# %%
table_.write("../True-PN-DR7LAMOST/DR7lamost-True-PN-duplicate-GAIA-PS1-final-saturated.ecsv", format="ascii.ecsv")
