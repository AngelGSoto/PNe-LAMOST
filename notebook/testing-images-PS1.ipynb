# %%
from astropy.io import fits
import matplotlib.pyplot as plt

# %%
hdul = fits.open("../True-PN-DR7LAMOST/t131.7227+17.8792.g.fits")  # open a FITS file
hdr = hdul[0].header  # the primary HDU header
hdr
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                  200 / length of data axis 1
# NAXIS2  =                  200 / length of data axis 2
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE    = '2023-10-09T17:00:22' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# CTYPE1  = 'RA---TAN'
# CTYPE2  = 'DEC--TAN'
# CRVAL1  =     129.767440795896
# CRVAL2  =     17.9999999999994
# CRPIX1  =              26905.5 / Reference pixel shifted for cutout
# CRPIX2  =                1701. / Reference pixel shifted for cutout
# CDELT1  = 6.94444461259988E-05
# CDELT2  = 6.94444461259988E-05
# PC001001=                  -1.
# ...

# %%
# Load the FITS image
image_data = fits.getdata("../True-PN-DR7LAMOST/t055.4309+52.2834.r.fits")

# %%
plt.figure()
plt.imshow(image_data, cmap='gray')
plt.colorbar()
