# %%
import pandas as pd

# %%
df = pd.read_csv("gaia_match/1661179085895O-result.csv")

# %%
df
# Out:
#               source_id          ra        dec  parallax  parallax_error  \
# 0   4057633557926034816  267.125460 -28.150361  1.087971        0.359906
# 1   4057670047959302656  267.412505 -27.766748  0.255216        0.560511
# 2   4067385916820955392  268.229518 -25.466371  0.060271        0.275532
# 3   4067385916826850560  268.228823 -25.466703       NaN             NaN
# 4   4117915726102856704  262.675325 -21.483629  0.325638        0.212314
# ..                  ...         ...        ...       ...             ...
# 68  4053276708751657344  264.728979 -35.183339  1.569265        0.733965
# 69  4053276708751657600  264.729333 -35.183701       NaN             NaN
# 70  4054437582556518528  262.617047 -33.766373  0.675318        0.252734
# 71  4055405908700614912  264.645421 -30.733212  0.709632        0.178830
# 72  4056774152141086208  266.708749 -30.266324  0.677528        0.483150
#
#          pmra  pmra_error     pmdec  ra_parallax_corr  dec_pmdec_corr  ...  \
# ...
